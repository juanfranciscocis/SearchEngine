# %%
import time
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Decorador de tiempo para calcular tiempo de ejecución

# %%
def timer_func(func):
    # This function shows the execution time of
    # the function object passed
    def wrap_func(*args, **kwargs):
        t1 = time.time()*10**12
        result = func(*args, **kwargs)
        t2 = time.time()*10**12
        return result , t2-t1
    return wrap_func

# %%
#Funcion Linear Search que sirve para buscar un elemento en una lista y encontrar la posición

# %%
@timer_func
def Linear_search(text, wordFind):
    posicion = []
    for i in range(len(text)):
        if text[i:i+len(wordFind)] == wordFind:
            posicion.append(i)

    return posicion

# %%
str = 'hola me llamo paula paula'
Linear_search(str, "paula")
# Out:
# ([14, 20], 9175040.0)

# %%
#Ejemplo para leer

# %%
wordSearchList = ['dui','aliquam','habitant','neque','nunc','commodo','libero','nulla','sapien','suscipit','viverra','mauris','nibh','nisi','nisl','nunc','odio','orci','ornare','pellentesque','pharetra','placerat','porta','porttitor','posuere','potenti','praesent','pretium','proin','pulvinar','purus','quam','quis','quisque','rhoncus','risus','rutrum','sagittis','sapien','scelerisque','sed','sem','semper','senectus','sit','sociis','sociosqu','sodales','sollicitudin','suscipit','suspendisse','taciti','tellus','tempor','tempus','tincidunt','torquent','tortor','tristique','turpis','ullamcorper','ultrices','ultricies','urna','ut','varius','vehicula','vel','velit','venenatis','vestibulum','vitae','vivamus','viverra','volutpat','vulputate']

# %%
#Funcion que lee un archivo y lo guarda en una lista y hace que las palabras esten en minusculas

# %%
with open('huge_txt_example.txt', 'r') as file:
    document = file.read()
#data to lowercase
document = document.lower()

# %%
#Funcion que busca la palabra en el documento y luego imprime la posición de las palabras

# %%
busqueda  = Linear_search(document,"dui")
busqueda
# Out:
# ([729,
#   852,
#   1001,
#   4814,
#   6019,
#   7251,
#   7387,
#   7773,
#   7846,
#   8517,
#   8836,
#   8990,
#   9947,
#   10924,
#   11038,
#   11483,
#   11537,
#   12442,
#   13515,
#   14379,
#   14886,
#   16268,
#   17063,
#   17081,
#   17533,
#   18937,
#   19419,
#   19984,
#   20211,
#   20372,
#   20494,
#   22005,
#   22016,
#   23047,
#   23211,
#   23461,
#   23564,
#   23753,
#   24666,
#   24742,
#   25079,
#   25105,
#   25228,
#   25704,
#   26482,
#   29154,
#   29706,
#   29740,
#   29817,
#   29862,
#   30103,
#   31536,
#   31777,
#   32422,
#   32516,
#   34820,
#   35138,
#   35614,
#   36199,
#   36528,
#   37093,
#   37711,
#   38604,
#   39299,
#   39646,
#   39769,
#   40001,
#   40506,
#   41051,
#   43255,
#   43987,
#   44394,
#   44703,
#   46043,
#   46601,
#   47427,
#   47821,
#   48168,
#   48783,
#   49123,
#   49424,
#   50160,
#   50548,
#   51137,
#   52178,
#   52924,
#   53045,
#   55007,
#   55350,
#   56031,
#   56938,
#   58351,
#   58704,
#   58926,
#   60174,
#   60248,
#   60449,
#   60578,
#   61514,
#   61628,
#   62069,
#   62169,
#   62977,
#   63192,
#   63314,
#   64719,
#   64994,
#   67692,
#   68106,
#   70061,
#   70228,
#   70307,
#   70746,
#   71551,
#   72048,
#   72371,
#   72737,
#   73332,
#   73708,
#   74321,
#   75492,
#   77204,
#   77487,
#   78179,
#   78784,
#   79260,
#   80863,
#   82641,
#   82734,
#   82806,
#   83242,
#   87254,
#   87662,
#   89193,
#   89549,
#   89558,
#   91278,
#   92865,
#   93715,
#   94693,
#   95411,
#   95473,
#   95615,
#   96337,
#   96485,
#   96653,
#   96841,
#   97154,
#   97601,
#   97826,
#   98945,
#   99729,
#   99801,
#   100273,
#   100851,
#   102711,
#   102956,
#   105766,
#   107737,
#   107941,
#   108320,
#   108811,
#   110005,
#   110063,
#   110420,
#   110517,
#   111137,
#   111353,
#   111504,
#   111575,
#   112202,
#   113390,
#   115075,
#   115264,
#   115456,
#   116234,
#   116319,
#   116570,
#   116967,
#   117048,
#   118136,
#   118327,
#   118606,
#   118663,
#   118974,
#   119279,
#   119328,
#   119695,
#   121189,
#   121669,
#   122255,
#   123917,
#   124187,
#   124399,
#   124703,
#   125511,
#   126030,
#   126372,
#   127631,
#   130078,
#   131651,
#   132291,
#   132759,
#   132842,
#   133679,
#   134279,
#   134415,
#   136373,
#   136408,
#   136703,
#   138879,
#   140761,
#   141685,
#   143422,
#   143475,
#   143851,
#   145520,
#   145607,
#   146042,
#   146673,
#   146975,
#   147049,
#   147444,
#   148106,
#   148412,
#   148787,
#   149333,
#   150307,
#   150425,
#   150818,
#   151939,
#   152630,
#   152833,
#   152857,
#   154314,
#   154389,
#   154616,
#   155059,
#   155347,
#   155678,
#   155990,
#   156144,
#   156398,
#   157861,
#   158324,
#   159419,
#   159453,
#   159490,
#   160260,
#   161101,
#   161165,
#   161315,
#   161786,
#   163412,
#   164965,
#   165379,
#   167207,
#   167754,
#   167787,
#   167856,
#   168045,
#   168804,
#   169405,
#   169857,
#   169997,
#   170151,
#   170172,
#   171005,
#   171689,
#   172551,
#   173754,
#   173837,
#   174240,
#   174773,
#   175427,
#   175625,
#   176459,
#   179111,
#   180950,
#   181314,
#   181559,
#   181854,
#   182131,
#   182185,
#   183072,
#   183846,
#   185014,
#   185191,
#   185864,
#   186349,
#   186421,
#   186733,
#   186997,
#   187958,
#   189017,
#   189819,
#   190428,
#   190652,
#   191489,
#   192193,
#   192514,
#   194363,
#   196343,
#   196380,
#   198113,
#   198142,
#   198732,
#   198833,
#   199661,
#   199844,
#   200383,
#   200714,
#   200845,
#   201746,
#   202307,
#   202381,
#   202466,
#   203443,
#   204010,
#   204576,
#   204875,
#   205212,
#   205280,
#   205374,
#   205426,
#   205989,
#   206643,
#   206891,
#   207134,
#   207343,
#   207375,
#   207699,
#   211197,
#   211306,
#   211499,
#   211710,
#   213114,
#   214278,
#   215117,
#   215907,
#   216068,
#   216519,
#   216548,
#   216839,
#   217245,
#   217418,
#   217744,
#   218031,
#   218592,
#   218660,
#   219618,
#   220567,
#   220774,
#   220851,
#   221814,
#   222208,
#   222285,
#   223272,
#   223329,
#   223599,
#   224729,
#   224902,
#   225493,
#   225684,
#   226797,
#   227578,
#   227706,
#   227777,
#   227827,
#   228359,
#   228627,
#   228932,
#   229223,
#   229759,
#   230270,
#   230806,
#   232157,
#   232352,
#   232404,
#   232808,
#   233056,
#   233673,
#   233747,
#   233891,
#   234085,
#   234218,
#   234241,
#   235181,
#   235569,
#   235988,
#   236771,
#   236973,
#   237376,
#   237898,
#   238983,
#   239456,
#   240127,
#   240219,
#   240381,
#   240395,
#   241306,
#   241406,
#   241943,
#   241970,
#   244605,
#   245363,
#   246306,
#   246709,
#   247764,
#   247840,
#   248334,
#   249146,
#   249923,
#   250397,
#   251073,
#   251178,
#   251533,
#   251568,
#   251681,
#   252629,
#   254666,
#   254813,
#   256795,
#   257166,
#   257492,
#   257780,
#   258089,
#   259619,
#   260987,
#   261321,
#   261503,
#   263550,
#   263788,
#   264442,
#   264574,
#   264713,
#   264760,
#   265007,
#   265907,
#   266018,
#   267268,
#   267611,
#   268513,
#   269165,
#   269216,
#   269628,
#   270078,
#   272416,
#   272634,
#   274770,
#   275505,
#   276124,
#   276447,
#   277018,
#   277170,
#   277324,
#   278325,
#   279569,
#   279822,
#   280210,
#   280319,
#   280641,
#   282690,
#   282974,
#   283399,
#   284492,
#   284655,
#   284873,
#   285593,
#   286000,
#   286539,
#   287026,
#   287832,
#   288375,
#   288684,
#   289797,
#   290048,
#   290568,
#   290808,
#   290937,
#   292107,
#   292203,
#   292436,
#   292898,
#   293182,
#   293748,
#   293830,
#   294173,
#   295053,
#   295391,
#   295692,
#   296121,
#   296177,
#   297709,
#   298297,
#   298653,
#   299190,
#   299318,
#   299974,
#   300005,
#   300455,
#   300904,
#   301153,
#   302773,
#   303079,
#   303635,
#   304195,
#   304602,
#   304886,
#   306598,
#   306801,
#   307965,
#   308092,
#   308670,
#   308990,
#   309786,
#   310033,
#   310090,
#   311195,
#   311726,
#   315309,
#   316786,
#   316832,
#   317916,
#   318185,
#   318513,
#   318621,
#   319777,
#   319850,
#   319957,
#   321686,
#   321841,
#   322022,
#   322442,
#   322470,
#   322555,
#   322713,
#   323004,
#   323102,
#   323254,
#   324073,
#   324408,
#   326465,
#   326974,
#   327056,
#   328289,
#   328396,
#   329392,
#   330811,
#   330852,
#   331828,
#   332105,
#   332248,
#   332874,
#   333139,
#   333659,
#   333829,
#   334105,
#   334829,
#   335037,
#   335795,
#   337176,
#   337229,
#   337630,
#   338831,
#   339066,
#   340489,
#   340834,
#   341774,
#   343342,
#   344107,
#   344300,
#   344500,
#   346050,
#   346160,
#   346304,
#   349203,
#   350337,
#   350423,
#   351006,
#   351547,
#   352172,
#   353148,
#   353494,
#   353679,
#   353969,
#   354749,
#   355301,
#   355324,
#   355689,
#   356200,
#   356671,
#   359715,
#   359955,
#   360283,
#   360665,
#   361001,
#   361442,
#   361463,
#   361541,
#   362269,
#   362317,
#   363261,
#   363282,
#   363946,
#   364207,
#   364765,
#   365297,
#   366793,
#   367408,
#   368439,
#   368693,
#   369363,
#   370745,
#   371450,
#   371628,
#   372498,
#   374056,
#   374115,
#   374243,
#   374882,
#   375641,
#   375917,
#   377579,
#   377894,
#   380513,
#   381436,
#   381516,
#   382789,
#   382944,
#   383272,
#   383561,
#   383908,
#   386154,
#   386737,
#   387754,
#   388101,
#   388363,
#   388634,
#   389134,
#   389701,
#   393450,
#   394249,
#   394812,
#   394924,
#   396917,
#   397106,
#   398073,
#   398375,
#   398635,
#   399945,
#   400471,
#   401051,
#   401627,
#   402762,
#   403262,
#   403658,
#   403990,
#   404281,
#   405325,
#   405700,
#   407881,
#   408696,
#   410494,
#   411705,
#   413664,
#   413739,
#   414244,
#   414337,
#   414393,
#   414600,
#   414651,
#   415081,
#   415624,
#   416380,
#   416422,
#   416484,
#   416897,
#   417066,
#   417492,
#   418198,
#   419018,
#   420248,
#   421270,
#   421450,
#   421525,
#   423021,
#   423077,
#   423403,
#   423724,
#   423749,
#   424229,
#   424611,
#   426063,
#   426143,
#   426225,
#   427619,
#   428323,
#   428706,
#   429446,
#   430459,
#   430560,
#   432622,
#   434968,
#   435493,
#   435498,
#   435664,
#   437429,
#   437497,
#   437890,
#   438657,
#   439039,
#   439351,
#   440873,
#   440975,
#   441514,
#   441690,
#   441792,
#   442465,
#   442559,
#   442683,
#   442749,
#   444024,
#   444339,
#   444737,
#   445052,
#   445407,
#   447406,
#   447780,
#   447855,
#   448916,
#   449711,
#   450242,
#   452827,
#   453124,
#   453540,
#   453578,
#   454448,
#   455317,
#   457001,
#   457909,
#   458202,
#   459116,
#   459366,
#   459757,
#   459794,
#   459860,
#   460149,
#   460406,
#   460411,
#   460809,
#   460884,
#   463312,
#   463488,
#   463766,
#   464382,
#   464891,
#   465758,
#   468088,
#   471925,
#   472202,
#   472762,
#   473093,
#   474085,
#   474260,
#   475841,
#   476446,
#   476468,
#   476571,
#   477672,
#   477743,
#   478538,
#   478889,
#   479031,
#   479055,
#   480727,
#   480925,
#   481093,
#   481310,
#   481968,
#   482707,
#   482963,
#   483769,
#   484237,
#   484933,
#   485046,
#   486308,
#   487813,
#   488779,
#   488910,
#   488951,
#   489785,
#   489868,
#   490626,
#   490982,
#   492625,
#   492989,
#   493192,
#   494386,
#   494985,
#   495861,
#   499252,
#   499316,
#   499531,
#   500968,
#   501083,
#   501882,
#   501999,
#   504110,
#   504181,
#   504693,
#   505412,
#   506616,
#   507086,
#   507349,
#   507420,
#   507570,
#   509662,
#   510402,
#   510558,
#   511068,
#   511110,
#   512696,
#   512738,
#   513088,
#   513335,
#   514642,
#   514869,
#   515450,
#   515630,
#   515784,
#   515818,
#   516669,
#   516746,
#   516870,
#   516905,
#   517711,
#   517779,
#   518653,
#   518791,
#   519326,
#   521335,
#   521406,
#   521875,
#   522253,
#   522451,
#   523308,
#   524183,
#   524925,
#   526046,
#   526927,
#   526997,
#   527577,
#   528644,
#   529449,
#   529591,
#   531015,
#   531866,
#   532143,
#   533280,
#   533763,
#   534623,
#   536791,
#   536818,
#   536955,
#   537027,
#   537112,
#   539283,
#   539385,
#   539637,
#   539718,
#   540142,
#   540449,
#   540651,
#   541527,
#   541579,
#   542207,
#   543491,
#   544033,
#   545043,
#   545580,
#   545623,
#   545875,
#   546170,
#   546802,
#   547043,
#   547406,
#   547844,
#   548500,
#   549742,
#   550082,
#   550384,
#   551862,
#   552149,
#   552186,
#   553961,
#   554856,
#   555584,
#   556547,
#   556809,
#   557109,
#   557378,
#   557802,
#   557859,
#   560506,
#   560642,
#   560839,
#   562381,
#   562610,
#   562924,
#   563906,
#   563972,
#   565755,
#   565961,
#   566072,
#   566875,
#   567210,
#   567954,
#   569217,
#   569299,
#   569381,
#   569596,
#   570181,
#   571406,
#   573555,
#   573703,
#   574772,
#   575476,
#   575542,
#   575986,
#   576793,
#   576928,
#   577066,
#   577303,
#   577367,
#   577525,
#   577905,
#   579319,
#   579597,
#   580370,
#   581738,
#   581837,
#   584249,
#   584611,
#   585092,
#   585179,
#   585274,
#   585944,
#   586108,
#   586582,
#   587209,
#   588808,
#   589811,
#   590190,
#   591434,
#   591710,
#   593532,
#   593848,
#   594690,
#   595081,
#   595433,
#   595669,
#   597228,
#   598307,
#   598427,
#   599010,
#   599429,
#   601201,
#   601367,
#   602270,
#   603622,
#   603761,
#   603909,
#   604163,
#   605498,
#   605990,
#   606868,
#   606957,
#   607502,
#   607739,
#   608111,
#   608617,
#   608652,
#   609024,
#   609618,
#   610336,
#   610384,
#   611545,
#   611616,
#   612162,
#   613042,
#   613265,
#   613371,
#   613774,
#   613878,
#   614396,
#   614823,
#   615800,
#   616366,
#   616791,
#   ...],
#  273262575616.0)

# %%
#Tiempo de ejecución de la función Linear Search

# %%
runtimeLinearSearch = []
for i in wordSearchList:
	search = Linear_search(document,i)
	runtimeLinearSearch.append(search[1])

# %%
print(runtimeLinearSearch)
# Out:
# [285380968448.0, 278380675072.0, 263258898432.0, 279233953792.0, 272327245824.0, 268352094208.0, 271549988864.0, 288508084224.0, 269622968320.0, 267099045888.0, 265458810880.0, 273601265664.0, 266289283072.0, 262817972224.0, 273786601472.0, 280693833728.0, 276909260800.0, 267710889984.0, 264694136832.0, 264101953536.0, 277812871168.0, 275737739264.0, 290764881920.0, 273272274944.0, 265829220352.0, 267820204032.0, 261481037824.0, 264469741568.0, 265449111552.0, 262869876736.0, 263228751872.0, 260876009472.0, 263929987072.0, 268741902336.0, 268699959296.0, 265715187712.0, 265213968384.0, 263340163072.0, 265655943168.0, 264203927552.0, 264599240704.0, 265567076352.0, 266388897792.0, 263385251840.0, 261775949824.0, 265938796544.0, 273839030272.0, 265308864512.0, 263500070912.0, 261569904640.0, 263406747648.0, 278478979072.0, 264990883840.0, 276309213184.0, 268215779328.0, 262763708416.0, 263766147072.0, 286178672640.0, 262811156480.0, 265656729600.0, 276419837952.0, 264138129408.0, 262950879232.0, 264198946816.0, 264033009664.0, 268551847936.0, 260826202112.0, 264533966848.0, 268966035456.0, 258999582720.0, 260364828672.0, 269498187776.0, 270586085376.0, 264672116736.0, 258775449600.0, 260376887296.0]

# %%
#Tabla de Datos de los tiempo que le tomo correr al algoritmo Linear Search

# %%
df = pd.DataFrame(zip(runtimeLinearSearch))
df.columns = [ 'Runtime Linear Search']
df
# Out:
#     Runtime Linear Search
# 0            2.853810e+11
# 1            2.783807e+11
# 2            2.632589e+11
# 3            2.792340e+11
# 4            2.723272e+11
# ..                    ...
# 71           2.694982e+11
# 72           2.705861e+11
# 73           2.646721e+11
# 74           2.587754e+11
# 75           2.603769e+11
#
# [76 rows x 1 columns]

# %%
#Grafica de los tiempos de ejecución de la función Linear Search

# %%
df.plot(y= 'Runtime Linear Search', figsize=(20,10), title='Runtime Linear Search')
# Out:
# <AxesSubplot: title={'center': 'Runtime Linear Search'}>

# %% [markdown]
# ## Linear Search

# %% [markdown]
# La funcion de busqueda de Linear Search busca la palabra que se le indica como manera directa, a lo que se refiere con esto es que busca palabras que sean iguales a la que se registro como opcion de busqueda. Para esto en el texto se establece una variable wordFind, ademas se inicializa un arreglo llamado posicion donde guardara la posicion dentro del texto de la palabra que se busco previamente en el texto. Luego se hace un lazo for que recorre todo el texto y busca la palabra que se le indico, si la encuentra la agrega al arreglo posicion y si no la encuentra no hace nada. Ademas dentro del lazo for se encuentra un if, este if me permite agregar al arreglo posicion las posiciones de palabras que sean iguales, es decir, si busca en mi texto la palabra "decir" y esta palabra se repite varias veces, entonces todas esas posiciones se guardan en el arreglo posicion. Al final de la funcion se retorna el arreglo posicion que contiene las posiciones de la palabra que se busco en el texto. Tambien se utiliza un decorador de tiempo para calcular el tiempo de ejecución de la funcion Linear Search. Para guardar todos estos tiempos cree un arreglo llamado runtimeLinearSearch donde se guardan los tiempos de ejecución de la funcion Linear Search.
#
# La complejidad de mi funcion Linear Search es O(n) ya que recorre todo el texto para buscar la palabra que se le indico. El mejor caso seria que encontrara la palabra en la posicion inicial, sin embargo, como es un texto largo la palabra puede repetirse lo que hace que la funcion Linear Search si sea de complejidad O(n). Por ultimo el uso de memoria de mi funcion Linear Search es O(1) ya que no se crea ninguna variable nueva, solo se utiliza la variable wordFind y el arreglo posicion, que me permite encontrar la posicion de la palabra que se busco en el texto.
